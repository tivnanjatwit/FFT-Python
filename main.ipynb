# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
fs = 100       # Sampling frequency in Hz
T = 1          # Duration in seconds
f1 = 5         # Frequency 1
f2 = 8         # Frequency 2

# Time vector
t = np.linspace(0, T, int(fs * T), endpoint=False)

# Sinusoids
s1 = np.sin(2 * np.pi * f1 * t)
s2 = .5 * np.sin(2 * np.pi * f2 * t)
# Signal: sum of two sinusoids
x = s1 + s2

# Plot the signal
plt.plot(t, s1)
plt.xlim(0,1)
plt.ylim(-1.5,1.5)
plt.title(f"Test Signal: sin(2π{f1}t)")
plt.show()

plt.plot(t, s2)
plt.xlim(0,1)
plt.ylim(-1.5,1.5)
plt.title(f"Test Signal: 0.5·sin(2π{f2}t)")
plt.show()

plt.plot(t, x)
plt.title(f"Test Signal: sin(2π{f1}t) + 0.5·sin(2π{f2}t)")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.show()

# %%
X = np.fft.fft(x)
freqs = np.fft.fftfreq(len(x), 1/fs)

# Take only the positive half (real signal is symmetric in frequency domain)
half_n = len(x) // 2
X_mag = np.abs(X[:half_n]) / len(x) * 2  # Normalize and scale
freqs = freqs[:half_n]

# Plot frequency spectrum
plt.stem(freqs, X_mag)
plt.title("Frequency Spectrum")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.grid(True)
plt.show()
